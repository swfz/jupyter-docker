# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x, y)
plt.show()

# %%
plt.hist(x)
# Out:
# (array([   2.,   17.,   87.,  145.,  247.,  239.,  147.,   78.,   27.,   11.]),
#  array([-3.20311445, -2.57268091, -1.94224736, -1.31181382, -0.68138028,
#         -0.05094674,  0.57948681,  1.20992035,  1.84035389,  2.47078743,
#          3.10122098]),
#  <a list of 10 Patch objects>)
